# %%
#BOOK STORE SHOP

def show_main_menu():
    print("===================================")
    print("      WELCOME TO BOOK STORE SHOP")
    print("===================================")

    while True:
        print("\n---------- Welcome to Book Store ----------")
        print("Available Categories :")
        print("1. Programming")
        print("2. Science")
        print("3. Literature")
        print("4. History")
        print("5. Motivation")
        print("6. Exit")
        print("-------------------------------------------")

        choice = int(input("Enter your choice (1-6): "))

        # ---------- PROGRAMMING BOOKS ----------
        if choice == 1:
            print("\nAvailable Categories of Programming Books:")
            print("1. Python Programming - ₹550")
            print("2. C Programming - ₹400")
            print("3. C++ Programming - ₹450")
            print("4. Java Programming - ₹500")
            print("5. Data Structures in Python - ₹600")
            print("===============================================")

            buy = input("Do you want to buy a book? (yes/no): ").lower()
            if buy == "yes":
                b = int(input("Enter book number to buy (1-5): "))
                qty = int(input("Enter quantity: "))
                if b == 1:
                    total = 550 * qty
                    print(f"You purchased {qty} Python Programming book(s). Total = ₹{total}")
                elif b == 2:
                    total = 400 * qty
                    print(f"You purchased {qty} C Programming book(s). Total = ₹{total}")
                elif b == 3:
                    total = 450 * qty
                    print(f"You purchased {qty} C++ Programming book(s). Total = ₹{total}")
                elif b == 4:
                    total = 500 * qty
                    print(f"You purchased {qty} Java Programming book(s). Total = ₹{total}")
                elif b == 5:
                    total = 600 * qty
                    print(f"You purchased {qty} Data Structures in Python book(s). Total = ₹{total}")
                else:
                    print(" Invalid book number.")
                payment_section()

        # ---------- SCIENCE BOOKS ----------
        elif choice == 2:
            print("\nAvailable Categories of Science Books:")
            print("1. Physics Fundamentals - ₹600")
            print("2. Chemistry Concepts - ₹500")
            print("3. Biology Basics - ₹450")
            print("4. Environmental Science - ₹550")
            print("5. Space Science - ₹700")
            print("===============================================")

            buy = input("Do you want to buy a book? (yes/no): ").lower()
            if buy == "yes":
                b = int(input("Enter book number to buy (1-5): "))
                qty = int(input("Enter quantity: "))
                if b == 1:
                    total = 600 * qty
                    print(f"You purchased {qty} Physics Fundamentals book(s). Total = ₹{total}")
                elif b == 2:
                    total = 500 * qty
                    print(f"You purchased {qty} Chemistry Concepts book(s). Total = ₹{total}")
                elif b == 3:
                    total = 450 * qty
                    print(f"You purchased {qty} Biology Basics book(s). Total = ₹{total}")
                elif b == 4:
                    total = 550 * qty
                    print(f"You purchased {qty} Environmental Science book(s). Total = ₹{total}")
                elif b == 5:
                    total = 700 * qty
                    print(f"You purchased {qty} Space Science book(s). Total = ₹{total}")
                else:
                    print(" Invalid book number.")
                payment_section()

        # ---------- LITERATURE BOOKS ----------
        elif choice == 3:
            print("\nAvailable Categories of Literature Books:")
            print("1. Hamlet - ₹300")
            print("2. Macbeth - ₹350")
            print("3. Pride and Prejudice - ₹400")
            print("4. Great Expectations - ₹450")
            print("5. The Odyssey - ₹380")
            print("===============================================")

            buy = input("Do you want to buy a book? (yes/no): ").lower()
            if buy == "yes":
                b = int(input("Enter book number to buy (1-5): "))
                qty = int(input("Enter quantity: "))
                if b == 1:
                    total = 300 * qty
                    print(f"You purchased {qty} Hamlet book(s). Total = ₹{total}")
                elif b == 2:
                    total = 350 * qty
                    print(f"You purchased {qty} Macbeth book(s). Total = ₹{total}")
                elif b == 3:
                    total = 400 * qty
                    print(f"You purchased {qty} Pride and Prejudice book(s). Total = ₹{total}")
                elif b == 4:
                    total = 450 * qty
                    print(f"You purchased {qty} Great Expectations book(s). Total = ₹{total}")
                elif b == 5:
                    total = 380 * qty
                    print(f"You purchased {qty} The Odyssey book(s). Total = ₹{total}")
                else:
                    print(" Invalid book number.")
                payment_section()

        # ---------- HISTORY BOOKS ----------
        elif choice == 4:
            print("\nAvailable Categories of History Books:")
            print("1. Indian History - ₹480")
            print("2. World History - ₹500")
            print("3. Ancient Civilizations - ₹550")
            print("4. Modern History - ₹600")
            print("5. Freedom Struggle of India - ₹520")
            print("===============================================")

            buy = input("Do you want to buy a book? (yes/no): ").lower()
            if buy == "yes":
                b = int(input("Enter book number to buy (1-5): "))
                qty = int(input("Enter quantity: "))
                if b == 1:
                    total = 480 * qty
                    print(f"You purchased {qty} Indian History book(s). Total = ₹{total}")
                elif b == 2:
                    total = 500 * qty
                    print(f"You purchased {qty} World History book(s). Total = ₹{total}")
                elif b == 3:
                    total = 550 * qty
                    print(f"You purchased {qty} Ancient Civilizations book(s). Total = ₹{total}")
                elif b == 4:
                    total = 600 * qty
                    print(f"You purchased {qty} Modern History book(s). Total = ₹{total}")
                elif b == 5:
                    total = 520 * qty
                    print(f"You purchased {qty} Freedom Struggle of India book(s). Total = ₹{total}")
                else:
                    print(" Invalid book number.")
                payment_section()

        # ---------- MOTIVATION BOOKS ----------
        elif choice == 5:
            print("\nAvailable Categories of Motivation Books:")
            print("1. The Power of Positive Thinking - ₹400")
            print("2. Atomic Habits - ₹500")
            print("3. Think and Grow Rich - ₹450")
            print("4. The 7 Habits of Highly Effective People - ₹550")
            print("5. You Can Win - ₹350")
            print("===============================================")

            buy = input("Do you want to buy a book? (yes/no): ").lower()
            if buy == "yes":
                b = int(input("Enter book number to buy (1-5): "))
                qty = int(input("Enter quantity: "))
                if b == 1:
                    total = 400 * qty
                    print(f"You purchased {qty} The Power of Positive Thinking book(s). Total = ₹{total}")
                elif b == 2:
                    total = 500 * qty
                    print(f"You purchased {qty} Atomic Habits book(s). Total = ₹{total}")
                elif b == 3:
                    total = 450 * qty
                    print(f"You purchased {qty} Think and Grow Rich book(s). Total = ₹{total}")
                elif b == 4:
                    total = 550 * qty
                    print(f"You purchased {qty} The 7 Habits of Highly Effective People book(s). Total = ₹{total}")
                elif b == 5:
                    total = 350 * qty
                    print(f"You purchased {qty} You Can Win book(s). Total = ₹{total}")
                else:
                    print(" Invalid book number.")
                payment_section()

        # ---------- EXIT ----------
        elif choice == 6:
            print("\n Thank you for visiting Book Store!")
            print("Have a great day")
            break

        else:
            print(" Invalid choice. Please enter a number between 1 and 6.")


# ---------- PAYMENT FUNCTION ----------
def payment_section():
    print("\n--- Select Payment Method ---")
    print("1. Cash")
    print("2. Credit/Debit Card")
    print("3. UPI (Google Pay / PhonePe / Paytm)")
    print("4. Net Banking")
    pay = int(input("Enter your choice (1-4): "))

    if pay in [1, 2, 3, 4]:
        print(" Payment Successful! Thank you for shopping at Book Store.")
    else:
        print("Invalid payment option. Please try again.")

show_main_menu()
# Out:
# ...
#       WELCOME TO BOOK STORE SHOP
# ...
#
# ---------- Welcome to Book Store ----------
# Available Categories :
# 1. Programming
# 2. Science
# 3. Literature
# 4. History
# 5. Motivation
# 6. Exit
# -------------------------------------------
#
# Available Categories of History Books:
# 1. Indian History - ₹480
# 2. World History - ₹500
# 3. Ancient Civilizations - ₹550
# 4. Modern History - ₹600
# 5. Freedom Struggle of India - ₹520
# ...
#
# ---------- Welcome to Book Store ----------
# Available Categories :
# 1. Programming
# 2. Science
# 3. Literature
# 4. History
# 5. Motivation
# 6. Exit
# -------------------------------------------
#
# Available Categories of Programming Books:
# 1. Python Programming - ₹550
# 2. C Programming - ₹400
# 3. C++ Programming - ₹450
# 4. Java Programming - ₹500
# 5. Data Structures in Python - ₹600
# ...
# You purchased 3 Java Programming book(s). Total = ₹1500
#
# --- Select Payment Method ---
# 1. Cash
# 2. Credit/Debit Card
# ...
